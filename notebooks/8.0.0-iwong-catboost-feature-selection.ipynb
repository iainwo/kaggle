# %%
import pandas as pd

# %% [markdown]
# ## Feature Importances

# %%
train_fi = pd.read_csv('../reports/train-feature-importances.csv')
val_fi = pd.read_csv('../reports/val-feature-importances.csv')

# %%
pd.concat([train_fi, val_fi], axis=1).head(50)
# Out:
#                                              col_name  \
# 0                                                 age
# 1                                         d1_spo2_min
# 2                                    gcs_motor_apache
# 3                                     d1_resprate_max
# 4                                          d1_bun_max
# 5           paired_elective_surgery_ventilated_apache
# 6                                    d1_heartrate_max
# 7                                 apache_3j_diagnosis
# 8                                    d1_heartrate_min
# 9                                          d1_bun_min
# 10                                         d1_wbc_min
# 11                                  gcs_verbal_apache
# 12                                     d1_lactate_min
# 13                                    gcs_eyes_apache
# 14                                 urineoutput_apache
# 15  paired_gender_icu_admit_source_apache_2_bodysy...
# 16                                        d1_temp_max
# 17                                                bmi
# 18                                    d1_resprate_min
# 19                                   pre_icu_los_days
# 20                                        d1_temp_min
# 21                                       d1_sysbp_min
# 22                                      d1_sodium_max
# 23    paired_apache_3j_bodysystem_apache_2_bodysystem
# 24                                    h1_resprate_min
# 25                  paired_ventilated_apache_lymphoma
# 26                           d1_sysbp_noninvasive_min
# 27                                h1_mbp_invasive_min
# 28                                     d1_glucose_min
# 29                                   d1_platelets_min
# 30                                             age_na
# 31                                         d1_mbp_min
# 32                                 d1_arterial_ph_min
# 33                                        fio2_apache
# 34                                  heart_rate_apache
# 35     paired_apache_post_operative_ventilated_apache
# 36                              d1_sysbp_invasive_max
# 37                               d1_pao2fio2ratio_max
# 38                                         map_apache
# 39                      paired_ventilated_apache_aids
# 40                                   icu_admit_source
# 41                                     d1_albumin_min
# 42                                       h1_sysbp_min
# 43         paired_gcs_unable_apache_ventilated_apache
# 44        paired_icu_admit_source_apache_2_bodysystem
# 45                               d1_arterial_pco2_min
# 46                                   h1_heartrate_min
# 47                                     d1_albumin_max
# 48                                  d1_hemaglobin_max
# 49                                       d1_sysbp_max
#
#     feature_importance_vals  \
# 0                  0.380294
# 1                  0.129469
# 2                  0.122695
# 3                  0.106485
# 4                  0.105886
# 5                  0.095005
# 6                  0.094078
# 7                  0.093769
# 8                  0.091214
# 9                  0.091134
# 10                 0.084289
# 11                 0.083639
# 12                 0.081608
# 13                 0.070715
# 14                 0.068258
# 15                 0.064869
# 16                 0.061621
# 17                 0.060834
# 18                 0.059900
# 19                 0.057106
# 20                 0.056815
# 21                 0.056587
# 22                 0.053411
# 23                 0.050572
# 24                 0.050015
# 25                 0.049918
# 26                 0.048818
# 27                 0.045476
# 28                 0.044468
# 29                 0.043368
# 30                 0.042639
# 31                 0.042088
# 32                 0.040454
# 33                 0.038503
# 34                 0.033937
# 35                 0.033461
# 36                 0.032804
# 37                 0.032765
# 38                 0.032525
# 39                 0.031836
# 40                 0.031401
# 41                 0.028763
# 42                 0.027958
# 43                 0.027744
# 44                 0.027416
# 45                 0.026890
# 46                 0.026562
# 47                 0.026429
# 48                 0.026146
# 49                 0.025794
#
#                                              col_name  feature_importance_vals
# 0                                                 age                 0.382015
# 1                                         d1_spo2_min                 0.129631
# 2                                    gcs_motor_apache                 0.122401
# 3                                          d1_bun_max                 0.106221
# 4                                     d1_resprate_max                 0.105469
# 5           paired_elective_surgery_ventilated_apache                 0.094916
# 6                                 apache_3j_diagnosis                 0.094260
# 7                                          d1_bun_min                 0.091462
# 8                                    d1_heartrate_max                 0.091223
# 9                                    d1_heartrate_min                 0.089779
# 10                                         d1_wbc_min                 0.083896
# 11                                  gcs_verbal_apache                 0.083733
# 12                                     d1_lactate_min                 0.078780
# 13                                    gcs_eyes_apache                 0.072439
# 14                                 urineoutput_apache                 0.068064
# 15  paired_gender_icu_admit_source_apache_2_bodysy...                 0.065321
# 16                                        d1_temp_max                 0.062035
# 17                                                bmi                 0.061598
# 18                                    d1_resprate_min                 0.059339
# 19                                        d1_temp_min                 0.057142
# 20                                   pre_icu_los_days                 0.056875
# 21                                       d1_sysbp_min                 0.055746
# 22                                      d1_sodium_max                 0.053399
# 23    paired_apache_3j_bodysystem_apache_2_bodysystem                 0.050525
# 24                  paired_ventilated_apache_lymphoma                 0.050040
# 25                                    h1_resprate_min                 0.049837
# 26                           d1_sysbp_noninvasive_min                 0.047980
# 27                                h1_mbp_invasive_min                 0.045482
# 28                                   d1_platelets_min                 0.045157
# 29                                     d1_glucose_min                 0.044663
# 30                                         d1_mbp_min                 0.041643
# 31                                             age_na                 0.040997
# 32                                 d1_arterial_ph_min                 0.040605
# 33                                        fio2_apache                 0.038650
# 34                                  heart_rate_apache                 0.033927
# 35                               d1_pao2fio2ratio_max                 0.033519
# 36     paired_apache_post_operative_ventilated_apache                 0.033424
# 37                              d1_sysbp_invasive_max                 0.032930
# 38                                         map_apache                 0.032437
# 39                                   icu_admit_source                 0.031869
# 40                      paired_ventilated_apache_aids                 0.031794
# 41                                     d1_albumin_min                 0.028675
# 42         paired_gcs_unable_apache_ventilated_apache                 0.027759
# 43                                       h1_sysbp_min                 0.027566
# 44        paired_icu_admit_source_apache_2_bodysystem                 0.027509
# 45                               d1_arterial_pco2_min                 0.027345
# 46                                   h1_heartrate_min                 0.026569
# 47                                  d1_hemaglobin_max                 0.026323
# 48                                     d1_albumin_max                 0.026178
# 49                                       d1_sysbp_max                 0.025639

# %%
feature_selection = list(val_fi.loc[:34, 'col_name'].unique())
feature_selection
# Out:
# ['age',
#  'd1_spo2_min',
#  'gcs_motor_apache',
#  'd1_bun_max',
#  'd1_resprate_max',
#  'paired_elective_surgery_ventilated_apache',
#  'apache_3j_diagnosis',
#  'd1_bun_min',
#  'd1_heartrate_max',
#  'd1_heartrate_min',
#  'd1_wbc_min',
#  'gcs_verbal_apache',
#  'd1_lactate_min',
#  'gcs_eyes_apache',
#  'urineoutput_apache',
#  'paired_gender_icu_admit_source_apache_2_bodysystem',
#  'd1_temp_max',
#  'bmi',
#  'd1_resprate_min',
#  'd1_temp_min',
#  'pre_icu_los_days',
#  'd1_sysbp_min',
#  'd1_sodium_max',
#  'paired_apache_3j_bodysystem_apache_2_bodysystem',
#  'paired_ventilated_apache_lymphoma',
#  'h1_resprate_min',
#  'd1_sysbp_noninvasive_min',
#  'h1_mbp_invasive_min',
#  'd1_platelets_min',
#  'd1_glucose_min',
#  'd1_mbp_min',
#  'age_na',
#  'd1_arterial_ph_min',
#  'fio2_apache',
#  'heart_rate_apache']
